# %%
import pandas as pd
mydata=pd.read_csv("/home/rgukt/Documents/Clean_Dataset.csv")
mydata
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.tail()
#
# NameError: name 'df' is not defined

# %%
sns.violinplot(x="days_left",y="duration",data=mydata)
plt.savefig('violinplot1.png')
plt.show()

# %%
sns.barplot(x="class",y="price",data=mydata)
plt.savefig('barplot.png')
plt.show()

# %%
sns.barplot(x="days_left",y="price",data=mydata)
plt.savefig('barplots.png')
plt.show()

# %%
sns.violinplot(x="days_left",y="price",data=mydata)
plt.savefig('violinplot.png')
plt.show()

# %%
sns.boxplot(x="days_left",y="class",data=mydata)
plt.savefig('b2.png')
plt.show()

# %%
sns.boxplot(x="duration",y="class",data=mydata)
plt.savefig('boxplot3.png')
plt.show()

# %%
sns.boxplot(x="days_left",y="duration",data=mydata)
plt.savefig('boxplot4.png')
plt.show()

# %%
sns.boxplot(x="price",y="class",data=mydata)
plt.savefig('boxplot5.png')
plt.show()

# %%
sns.boxplot(x="days_left",y="duration",data=mydata)
plt.savefig('boxplot6.png')
plt.show()

# %%
sns.stripplot(x="destination_city",y="departure_time",data=mydata)
plt.savefig('stripplot8.png')
plt.show()

# %%
sns.pairplot([mydata],hue = 'Source')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 sns.pairplot([mydata],hue = 'Source')
#       2 plt.show()
#
# NameError: name 'sns' is not defined
